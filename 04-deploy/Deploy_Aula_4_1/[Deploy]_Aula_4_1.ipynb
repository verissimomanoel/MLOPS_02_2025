# %% [markdown]
# # Tutoria ML: Deploy

# %% [markdown]
# ## 📚 Índice

# %% [markdown]
# ### 1 - Introdução ao Deploy de Modelos
#
# - Conceito de deploy em Machine Learning
# - Desafios comuns: escalabilidade, reprodutibilidade e monitoramento
# - MLOps
# - Implementando MLOps na empresa
#
# ---
#
# ### 2 - Infraestrutura: On-Premises vs Cloud
#
# - Diferenças entre ambientes locais e em nuvem
# - Custos, escalabilidade, segurança e manutenção
# - Quando escolher cada tipo de ambiente
#
# ---
#
# ### 3 - Modelos de serviço em computação em nuvem: IaaS, PaaS e CaaS
#
# - Definições e diferenças entre _Infrastructure as a Service_, _Platform as a Service_ e _Container as a Service_
# - Exemplos práticos (EC2, Lambda, ECS e Fargate)
# - Implicações no deploy de modelos de ML
#
# ---
#
# ### 4 - Estratégias de Deploy
#
# - Padrões de rollout e atualização:
#   - **Blue/Green Deployment**
#   - **Canary Deployment**
#   - **Shadow Deployment**
#
# ---
#
# ### 5 - Artefatos
#
# - Artefatos gerados após o treino:
#   - Modelo serializado
#   - Dependências
#   - Código de inferência
#
# ---
#
# ### 6 - Formas de Servir Modelos
#
# - **Meios de processamento da inferência:**
#   - **Batch Serving**
#   - **Online Serving**
#   - **Streaming Serving**
#   - **Event-Driven Serving**
# - **Padrões de _Model Serving_:**
#   - Modelo Embutido (_Embedded Model_)
#   - Modelo como Serviço (_Model as a Separate Service_)
#
# ---

# %% [markdown]
# ## 1 - Introdução ao deploy de modelos

# %% [markdown]
# **Breve definição da palavra "Deploy"**: <br><br> "é colcoar em produção uma aplicação que teve o seu desenvolvimento concluído, fazendo com que fique disponível para consumo de algum outro serviço ou grupo de usuários"

# %% [markdown]
# ### 🚀 O que significa "colocar um modelo em produção"?
#
# > ⚠️ **Lembre-se:** “produção” não tem o mesmo significado para todos.
# > Ela é um **espectro**, que pode variar muito entre equipes e projetos.
#
# ### 💡 Exemplos:
#
# - Para algumas equipes, **colocar em produção** significa apenas
#   gerar **gráficos e relatórios** a partir dos resultados de um notebook
#   para apresentar ao time de negócios.
#
# - Para outras, significa **manter modelos disponíveis 24/7**,
#   respondendo **milhões de requisições de usuários por dia**,
#   com **monitoramento, escalabilidade e alta confiabilidade**.
#
# ---

# %% [markdown]
# ### Desafios comuns: escalabilidade, reprodutibilidade e monitoramento

# %% [markdown]
# Ao levar um modelo de Machine Learning para produção, o objetivo não é apenas que ele funcione mas que ele funcione **de forma confiável, previsível e sustentável**.
# Três princípios fundamentais orientam esse processo: **escalabilidade**, **reprodutibilidade** e **monitoramento**.

# %% [markdown]
# #### 🧗 Escalabilidade

# %% [markdown]
# Um modelo precisa ser capaz de **atender à demanda real de uso**, seja para dezenas ou milhões de requisições.
# A escalabilidade garante que o sistema possa **crescer horizontal ou verticalmente** sem perda significativa de desempenho.
# Isso envolve decisões de arquitetura, como uso de **containers**, **orquestradores (Kubernetes, ECS)** e **balanceadores de carga**.

# %% [markdown]
# > Exemplo: um modelo de recomendação que atende 100 usuários em testes deve manter a mesma qualidade e velocidade quando atender 100 mil.

# %% [markdown]
# #### 🔁 Reprodutibilidade

# %% [markdown]
# A reprodutibilidade assegura que o mesmo modelo, quando reimplantado, produza **resultados idênticos** nas mesmas condições.
# É o que permite **confiar no processo de deploy**, rastrear experimentos e reproduzir pipelines de treinamento e inferência.
# Boas práticas incluem:
#
# - Controle de versão de código e dados
# - Armazenamento de artefatos e hiperparâmetros
# - Uso de ambientes padronizados (Docker, Conda, IaC)

# %% [markdown]
# > Em outras palavras: se não for reproduzível, não está pronto para produção.

# %% [markdown]
# #### 👀 Monitoramento

# %% [markdown]
# Após o deploy, o trabalho **não termina**, ele **começa**.
# Monitorar é essencial para garantir que o modelo continue entregando valor com o tempo.
# Isso envolve:
#
# - **Métricas técnicas:** latência, throughput, erros de API
# - **Métricas de performance do modelo:** acurácia, F1, drift de dados
# - **Alertas e logs** para detectar falhas e quedas de desempenho

# %% [markdown]
# > Modelos envelhecem — e o monitoramento é o que nos permite detectar _quando_ e _por que_ isso acontece.

# %% [markdown]
# #### 📑 Em resumo:
#
# | Princípio             | Foco Principal                     | Ferramentas/Boas Práticas                         |
# | :-------------------- | :--------------------------------- | :------------------------------------------------ |
# | **Escalabilidade**    | Desempenho e disponibilidade       | Kubernetes/ECS, Load Balancer, Auto Scaling       |
# | **Reprodutibilidade** | Consistência entre ambientes       | Git, DVC, MLflow, Docker                          |
# | **Monitoramento**     | Confiabilidade e melhoria contínua | Prometheus, Grafana, Evidently AI, AWS CloudWatch |

# %% [markdown]
# ### MLOps

# %% [markdown]
# Com o aumento do uso de modelos de machine learning em produtos reais, surge um novo desafio: como colocar modelos em produção de forma **confiável, escalável e contínua**.
# Assim como o DevOps transformou o ciclo de desenvolvimento de software tradicional, o MLOps (Machine Learning Operations) aplica princípios semelhantes: automação, integração contínua e monitoramento ao ciclo de vida de modelos de ML.

# %% [markdown]
# MLOps é um conjunto de práticas, ferramentas e processos que unem cientistas de dados, engenheiros de machine learning e equipes de operações, com o objetivo de:
#
# - Automatizar o treinamento, validação e implantação de modelos;
# - Garantir reprodutibilidade dos experimentos e versões de modelos;
# - Monitorar desempenho e detectar drift em produção;
# - Integrar CI/CD ao pipeline de aprendizado de máquina.

# %% [markdown]
# ![The ML-Lifecycle: Detailed View](./images/3-ML-Lifecycle-Detail.jpg)

# %% [markdown]
# 🔁 **Ciclo de Vida em MLOps**
#
# 1. Coleta e preparo de dados
# 2. Treinamento e validação de modelos
# 3. Empacotamento e versionamento
# 4. Implantação (deployment)
# 5. Monitoramento e re-treinamento
#
# Cada etapa é automatizada e integrada, reduzindo o tempo entre pesquisa e entrega de valor em produção.

# %% [markdown]
# 🧩 Benefícios
#
# - Redução de erros manuais
# - Ciclos mais curtos entre desenvolvimento e entrega
# - Escalabilidade e rastreabilidade
# - Modelos sempre atualizados e em melhoria contínua

# %% [markdown]
# ### Implementando MLOps na empresa

# %% [markdown]
# Existem **três níveis de implementação de MLOps**, que variam conforme o grau de automação e maturidade do processo dentro da organização.

# %% [markdown]
# #### 🧩 MLOps Nível 0 — O Início da Jornada

# %% [markdown]
# > 🔰 **Primeiro passo na adoção de sistemas de Machine Learning**
#
# O **Nível 0** do MLOps representa o estágio inicial, caracterizado por **fluxos de trabalho totalmente manuais** e processos conduzidos principalmente por **cientistas de dados**.
#
# ---
#
# ⚙️ Características Principais
#
# - 🧑‍🔬 **Processos manuais:**
#   Todas as etapas — desde a preparação dos dados até a validação do modelo — são realizadas manualmente.
#
# - 🪜 **Execução isolada:**
#   Cada fase do pipeline é executada separadamente, exigindo transições manuais entre as etapas.
#
# - 📦 **Entrega de modelos como artefatos:**
#   Os cientistas de dados fornecem os modelos treinados para que a equipe de engenharia realize o **deploy** em infraestrutura de APIs.
#
# - 🚧 **Separação entre equipes:**
#   Há uma divisão clara entre quem **cria** o modelo e quem **implanta** em produção.
#
# ---
#
# 📉 Limitações do Nível 0
#
# > ❌ **Baixa automação, pouca frequência de entregas e ausência de monitoramento.**
#
# - As **atualizações de modelos** ocorrem poucas vezes por ano.
# - Não há **integração contínua (CI/CD)** entre os modelos e o restante do código da aplicação.
# - Falta de **monitoramento ativo** do desempenho dos modelos em produção.
#
# ---
#
# 💭 Em resumo
# O **MLOps Nível 0** é o ponto de partida: o foco ainda está em provar valor com machine learning, **antes de estruturar automação e integração** entre as etapas do ciclo de vida dos modelos.

# %% [markdown]
# #### ⚙️ MLOps Nível 1 — Automação e Treinamento Contínuo

# %% [markdown]
# > 🚀 **Transição do processo manual para a automação do ciclo de Machine Learning.**
#
# O **Nível 1** é indicado para organizações que desejam **treinar os mesmos modelos de forma recorrente com dados atualizados**.
# O principal objetivo aqui é **automatizar o pipeline de ML**, permitindo o **treinamento contínuo dos modelos**.
#
# ---
#
# 🔄 Diferença em relação ao Nível 0
#
# No **Nível 0**, apenas o **modelo treinado** é implantado em produção.
# Já no **Nível 1**, o que se implanta é **todo o pipeline de treinamento**, que:
#
# - É executado periodicamente;
# - Gera novos modelos automaticamente;
# - Garante **entrega contínua (Continuous Delivery)** do serviço de predição.
#
# ---
#
# 🧠 Principais Características do Nível 1
#
# - ⚡ **Experimentação mais rápida:**
#   Maior automação em etapas de teste e validação.
#
# - 🔁 **Treinamento contínuo:**
#   O modelo é re-treinado com **dados atualizados** de produção.
#
# - 🧩 **Padronização de ambientes:**
#   O mesmo pipeline é usado em **desenvolvimento**, **pré-produção** e **produção**.
#
# - 🤝 **Colaboração entre times:**
#   Engenheiros e cientistas de dados criam **componentes modulares e reutilizáveis**.
#
# - 🗃️ **Feature Store centralizada:**
#   Armazena e padroniza as **features** usadas no treinamento e na inferência.
#
# - 🧾 **Gestão de metadados:**
#   Cada execução do pipeline é registrada, permitindo **rastreabilidade** e **reprodutibilidade** dos experimentos.
#
# ---
#
# 💬 Em resumo
#
# > O **MLOps Nível 1** representa o início da **automação real** em machine learning:
# > pipelines automatizados, dados atualizados e colaboração integrada entre equipes.

# %% [markdown]
# #### 🧠 MLOps Nível 2 — Escala, Orquestração e Automação Completa

# %% [markdown]
# > ⚡ **O ápice da maturidade em MLOps — quando o aprendizado de máquina se torna contínuo e em larga escala.**
#
# O **Nível 2** é voltado para organizações que realizam **experimentação intensiva** e desenvolvem **novos modelos com alta frequência**, exigindo **treinamento e implantação contínuos**.
#
# Esse estágio é característico de **empresas de tecnologia avançada (_tech companies_)**, que:
#
# - Atualizam seus modelos em **minutos**,
# - Realizam **treinamentos horários ou diários**, e
# - Executam **deploys em larga escala**.
#
# ---
#
# 🏗️ Componentes Adicionais do Nível 2
#
# O Nível 2 inclui **todos os elementos do Nível 1**, e adiciona:
#
# - 🧩 **Orquestrador de pipelines de ML:**
#   Responsável por gerenciar e coordenar diversos pipelines de treinamento e deploy.
#
# - 🗂️ **Registro de modelos (_Model Registry_):**
#   Permite rastrear versões, experimentos e implantações de diferentes modelos de forma centralizada.
#
# ---
#
# 🔁 Ciclo de Entrega Contínua em Escala
#
# O fluxo no Nível 2 é composto por **três estágios principais**, repetidos continuamente e em larga escala:
#
# 1. 🏗️ **Construção do pipeline**
#    Envolve experimentação com novos modelos e algoritmos, garantindo que as etapas estejam devidamente **orquestradas**.
#    ➜ _Resultado:_ código-fonte dos pipelines, versionado em um repositório.
#
# 2. 🚀 **Implantação do pipeline**
#    O código é **construído, testado e empacotado** para gerar componentes prontos para deploy.
#    ➜ _Resultado:_ pipeline funcional implantado com a nova versão do modelo.
#
# 3. 🧩 **Serviço do pipeline**
#    O pipeline é disponibilizado como um **serviço de predição** para as aplicações.
#    Estatísticas e métricas são coletadas em **tempo real**, gerando **gatilhos automáticos** para novas execuções ou ciclos de reexperimentos.
#    ➜ _Resultado:_ aprendizado de máquina **contínuo, automatizado e autossustentável**.
#
# ---
#
# 💬 Em resumo
#
# > O **MLOps Nível 2** representa o estágio de **maturidade total**:
# > múltiplos pipelines em orquestração, automação completa e modelos que **aprendem e evoluem constantemente**.

# %% [markdown]
# #### ⛮ Diferenças entre MLOps e DevOps

# %% [markdown]
# > ⚠️ Tanto o MLOps quanto o DevOps são práticas voltadas a aprimorar os processos de desenvolvimento, implantação e monitoramento de aplicações.
# > No entanto, cada um aborda desafios distintos dentro desse ciclo.

# %% [markdown]
# 🚀 DevOps
#
# O **DevOps** surgiu com o objetivo de **reduzir a distância entre as equipes de desenvolvimento e operações**.
# Ele busca garantir que alterações de código sejam:
#
# - ✅ **Testadas automaticamente**
# - 🔁 **Integradas de forma contínua**
# - 🚢 **Implantadas com eficiência e confiabilidade**
#
# Além disso, o DevOps promove uma **cultura de colaboração constante**, com foco em:
#
# > 🔹 Ciclos de entrega mais rápidos
# > 🔹 Maior qualidade das aplicações
# > 🔹 Melhor uso dos recursos de infraestrutura
#
# ---
#
# 🤖 MLOps
# O **MLOps**, por outro lado, é um conjunto de práticas **inspiradas no DevOps**, mas **voltadas especificamente para projetos de _Machine Learning_**.
#
# Enquanto o deploy de software tradicional é relativamente direto, o ciclo de ML envolve etapas mais complexas, como:
#
# - 📊 **Coleta e preparo de dados**
# - 🧠 **Treinamento e validação de modelos**
# - 🚀 **Implantação em produção**
# - 🔄 **Monitoramento e re-treinamento contínuos**
#
# > Em resumo, o MLOps traz os princípios do DevOps para o aprendizado de máquina, garantindo **automação, confiabilidade e melhoria contínua** em todo o ciclo de vida dos modelos.

# %% [markdown]
# ## 2 - Infraestrutura: On-Premises vs Cloud

# %% [markdown]
# ### Infraestrutura: On-Premises vs Cloud

# %% [markdown]
# Quando falamos de **infraestrutura para Machine Learning e MLOps**, uma das decisões mais importantes é **onde** nossos sistemas e modelos vão rodar:
# no **ambiente local (on-premises)** ou na **nuvem (cloud)**.

# %% [markdown]
# #### 🏢 On-Premises (Infraestrutura Local)

# %% [markdown]
# É o modelo **tradicional**, onde toda a infraestrutura, servidores, armazenamento, rede e segurança — fica **fisicamente dentro da organização**.

# %% [markdown]
# ⚙️ Características:
#
# - A empresa **compra, configura e mantém** os servidores;
# - Controle total sobre **hardware, segurança e dados**;
# - Requer **equipe técnica dedicada** e altos **custos de manutenção**;
# - Atualizações e escalabilidade dependem de **novos investimentos físicos**.
#
# ✅ Vantagens:
#
# - Total **controle** sobre recursos e segurança;
# - Pode ser **mais econômico a longo prazo** em cenários estáveis e previsíveis;
# - Adequado para **dados sensíveis** (bancos, hospitais, governos).
#
# ⚠️ Desvantagens:
#
# - Alto **custo inicial (CAPEX)**;
# - Escalabilidade **lenta** e limitada pela capacidade física;
# - Exige **gestão complexa** de hardware e rede.
#
# ---

# %% [markdown]
# ### ☁️ Cloud (Computação em Nuvem)

# %% [markdown]
# Nesse modelo, a infraestrutura é **fornecida como serviço** por provedores como **AWS, Azure, GCP** ou **Oracle Cloud**.
# A empresa paga apenas **pelo que usa** e pode ajustar os recursos conforme a demanda.

# %% [markdown]
# ⚙️ Características:
#
# - Provisionamento rápido de **máquinas, bancos de dados e redes virtuais**;
# - Custos baseados em **uso (OPEX)**, sem necessidade de comprar hardware;
# - Facilidade para **automatizar, escalar e monitorar** recursos;
#
# ✅ Vantagens:
#
# - **Escalabilidade imediata** e flexível;
# - **Menor tempo de setup**;
# - Recursos avançados de **IA, segurança e monitoramento** prontos para uso;
# - **Disponibilidade global** (multi-regiões e zonas de redundância);
#
# ⚠️ Desvantagens:
#
# - **Custo variável** — pode subir rápido se mal gerenciado;
# - **Menor controle** sobre infraestrutura física;
# - **Dependência do provedor** (vendor lock-in).

# %% [markdown]
# ### ⚖️ **Comparativo Rápido**

# %% [markdown]
# | Aspecto                  | On-Premises                    | Cloud                            |
# | ------------------------ | ------------------------------ | -------------------------------- |
# | **Custo inicial**        | Alto (compra de hardware)      | Baixo (pago pelo uso)            |
# | **Escalabilidade**       | Limitada e lenta               | Imediata e elástica              |
# | **Controle**             | Total                          | Parcial                          |
# | **Manutenção**           | Interna                        | Responsabilidade do provedor     |
# | **Segurança**            | Alta, mas dependente da equipe | Alta, com recursos automatizados |
# | **Flexibilidade**        | Baixa                          | Alta                             |
# | **Tempo de implantação** | Demorado                       | Rápido                           |

# %% [markdown]
# ## 3 - Modelos de serviço em computação em nuvem: IaaS, PaaS e CaaS

# %% [markdown]
# A computação em nuvem oferece diferentes **níveis de abstração**, que variam de **infraestrutura bruta** até **plataformas totalmente gerenciadas**.
# Entender essas camadas é essencial para escolher **onde investir tempo, controle e automação** dentro de um pipeline de **MLOps**.
#
# > 💡 **Principais modelos:**
# >
# > - **IaaS (Infrastructure as a Service)** → controle total
# > - **CaaS (Container as a Service)** → controle via containers
# > - **PaaS (Platform as a Service)** → foco em código e automação

# %% [markdown]
# ### IaaS - Infraestructure as a Service

# %% [markdown]
# No modelo **IaaS**, o provedor oferece os **blocos básicos da infraestrutura**: máquinas virtuais, rede, armazenamento e segurança.
# Você gerencia o sistema operacional, as dependências e as aplicações.

# %% [markdown]
# **Exemplos**
#
# - **AWS EC2 (Elastic Compute Cloud)**
# - **Google Compute Engine**
# - **Azure Virtual Machines**
# - **OpenStack**, **VMware vSphere**

# %% [markdown]
# ✅ Vantagens:
#
# - **Total controle** sobre o ambiente.
# - Ideal para **infraestruturas personalizadas** e pipelines complexos.
# - Permite uso de **GPU/TPU** sob medida.
#
# ⚠️ Desvantagens:
#
# - Exige **gestão manual** (rede, SO, patches, segurança).
# - **Provisionamento mais lento** e maior carga operacional.
#
# 🧠 Ideal para:
#
# > Ambientes que exigem **configuração detalhada** ou integração com sistemas legados.

# %% [markdown]
# ### PaaS - Platform as a Service

# %% [markdown]
# **PaaS** oferece uma **plataforma completa** para desenvolvimento e execução de aplicações,
# sem necessidade de gerenciar infraestrutura, rede ou containers diretamente.
#
# > Você foca no **código e nas aplicações**, e o provedor cuida da **infraestrutura, escalabilidade e deploy**.

# %% [markdown]
# Exemplos Modernos (Serverless & AI Platforms):
#
# - **AWS Lambda** → execução de funções sob demanda
# - **AWS Fargate / Cloud Run / Azure Container Apps** → containers sem servidor
# - **Databricks**, **Vertex AI**, **SageMaker** → PaaS voltado para ML e MLOps

# %% [markdown]
# ✅ Vantagens:
#
# - **Deploy rápido e automatizado**.
# - **Escalabilidade automática** sem gerenciamento de servidores.
# - Integração com **pipelines CI/CD e monitoramento nativo**.
# - Ideal para **prototipagem e inferência serverless**.
#
# ⚠️ Desvantagens:
#
# - **Menor controle** sobre o ambiente de execução.
# - Possibilidade de **vendor lock-in** (dependência do provedor).
#
# 🧠 Ideal para:
#
# > Times que buscam **agilidade e produtividade**,
# > priorizando **foco em modelo, dados e entrega de valor**.

# %% [markdown]
# ### CaaS Container as a Service

# %% [markdown]
# O **CaaS** é uma camada intermediária entre IaaS e PaaS.
#
# Ele abstrai a infraestrutura bruta e fornece um **ambiente gerenciado para rodar containers** (como Docker e Kubernetes).
# Você não se preocupa com VMs diretamente, mas ainda controla a **orquestração, escalabilidade e deploy** dos containers.

# %% [markdown]
# Exemplos:
#
# - **AWS ECS (Elastic Container Service)**
# - **AWS EKS (Elastic Kubernetes Service)**
# - **Google Kubernetes Engine (GKE)**
# - **Azure Kubernetes Service (AKS)**
# - **Red Hat OpenShift**
# - **Docker Swarm**
#
# ✅ Vantagens:
#
# - Excelente equilíbrio entre **controle e automação**.
# - **Portabilidade** — containers podem rodar em qualquer nuvem.
# - Integração perfeita com **pipelines CI/CD** e **deploy contínuo**.
# - Ideal para **serviços distribuídos e microserviços**.
#
# ⚠️ Desvantagens:
#
# - Requer **conhecimento em containers e orquestração**.
# - A **complexidade aumenta** com o número de serviços.
#
# 🧠 Ideal para:
#
# > Times de **engenharia e MLOps** que querem **automatizar deploys e escalar modelos**
# > usando containers de forma padronizada e reproduzível.

# %% [markdown]
# ### ⚖️ Comparativo Rápido

# %% [markdown]
# | Aspecto                  | **IaaS**                        | **CaaS**                            | **PaaS**                                 |
# | ------------------------ | ------------------------------- | ----------------------------------- | ---------------------------------------- |
# | **Nível de abstração**   | Baixo                           | Médio                               | Alto                                     |
# | **Controle**             | Total (infraestrutura completa) | Parcial (containers e orquestração) | Limitado (foco no código)                |
# | **Responsabilidade**     | Usuário gerencia tudo           | Usuário gerencia containers         | Provedor gerencia tudo                   |
# | **Escalabilidade**       | Manual                          | Orquestrada                         | Automática                               |
# | **Complexidade**         | Alta                            | Média                               | Baixa                                    |
# | **Velocidade de deploy** | Lenta                           | Moderada                            | Rápida                                   |
# | **Exemplos**             | EC2, GCE, Azure VM              | EKS, GKE, ECS, AKS                  | Lambda, App Engine, Cloud Run, SageMaker |

# %% [markdown]
# ## 4 - Estratégias de deploy

# %% [markdown]
# Quando um novo modelo ou versão de aplicação está pronto para produção, surge uma questão crítica:
#
# > 💡 **Como fazer o deploy de forma segura, sem interromper o serviço e sem afetar os usuários?**
#
# Essa é a função dos **padrões de rollout (implantação)** e **atualização**, estratégias que determinam **como as novas versões são disponibilizadas** em produção.

# %% [markdown]
# Os **padrões de rollout** surgem justamente para **reduzir riscos**, permitindo:
#
# - **Atualizações contínuas** sem downtime;
# - **Comparação entre versões** (ex: modelo antigo vs novo);
# - **Rollback rápido** em caso de falhas;
# - **Monitoramento gradual** de métricas e impacto.

# %% [markdown]
# ### O que são Padrões de Rollout?

# %% [markdown]
# São **estratégias controladas de implantação**, que definem **como** e **quando** o novo código ou modelo substitui o antigo em produção.
#
# Esses padrões permitem uma transição **segura, observável e reversível**, garantindo que:
#
# - O **impacto seja testado gradualmente**;
# - Os **usuários não percebam interrupções**;
# - E seja possível **voltar rapidamente** à versão anterior, se necessário.

# %% [markdown]
# ### Principais tipos (que veremos a seguir)

# %% [markdown]
# | Padrão                    | Descrição resumida                                                                               |
# | ------------------------- | ------------------------------------------------------------------------------------------------ |
# | **Blue-Green Deployment** | Mantém duas versões ativas, muda o tráfego para a nova após testes.                              |
# | **Canary Deployment**     | Direciona parte do tráfego (ex: 5%) para a nova versão antes da troca total.                     |
# | **Shadow Deployment**     | Roteia o tráfego duplicado para a nova versão apenas para monitoramento (sem impactar usuários). |

# %% [markdown]
# ### 💙💚 Blue-Green Deployment

# %% [markdown]
# <img src="./images/blue-green.jpg" alt="blue-green-deployment" width="500"/>

# %% [markdown]
# #### 🎯 Ideia central

# %% [markdown]
# Imagine que você tem **duas versões** de seu serviço ou modelo rodando _ao mesmo tempo_, em ambientes separados:
#
# - **Blue**: a versão atual, que os usuários estão usando
# - **Green**: a nova versão, preparada para ser liberada
#
# Quando a versão “Green” estiver testada e pronta, o tráfego (uso real) é redirecionado do Blue para o Green. Se algo der errado, basta voltar o tráfego para o Blue. Essa estratégia dá **quase zero de downtime** e permite **rollbacks rápidos**.

# %% [markdown]
# #### Benefícios

# %% [markdown]
# 1. **Isolamento entre versões**
#    Ao rodar **Blue e Green em infraestruturas separadas**, a nova versão pode ser testada sem interferir na versão atual. Isso diminui drasticamente o risco de um deploy quebrar tudo.
#
# 2. **Rollback simples**
#    Se algo der errado com o novo ambiente (Green), basta redirecionar o tráfego de volta para o Blue, sem necessidade de “reinstalar do zero”.
#
# 3. **Testes reais antes da mudança total**
#    Você pode rotear uma pequena fração do tráfego real para o Green antes de mudar tudo. Isso é como um “canary test” dentro de um deploy Blue/Green.
#
# 4. **Eficiência de custo e otimização**
#    Como os ambientes são independentes, a nova versão pode usar recursos diferentes: talvez menos, talvez mais, dependendo da necessidade. Quando o deploy for bem-sucedido, você desativa o ambiente antigo e para de pagar por ele.

# %% [markdown]
# #### 🚫 Quando _NÃO_ usar

# %% [markdown]
# 1. **Dependências de banco de dados ou esquema de dados fortemente acopladas**
#
#    - Se a sua aplicação faz mudanças de esquema de dados que **não podem ser facilmente desacopladas** do código, criar um ambiente “Green” separado torna-se muito difícil.
#    - A latência ou degradação de desempenho podem surgir se o Green estiver em local geográfico diferente ou usar datastores replicados de maneira ineficiente.
#
# 2. **Aplicação que exige “conhecimento de deploy” embutido ou controle de feature flags elevado**
#    - Se a aplicação muda de comportamento dependendo se está em Blue ou em Green (como rotinas de sincronização, ativação de flags, etc) — então o benefício de imutabilidade se perde.
#    - O padrão Blue/Green funciona melhor quando a infraestrutura é imutável: você troca o ambiente inteiro, em vez de adicionar lógica condicional ao código.

# %% [markdown]
# ### 🐣 Canary Deployment

# %% [markdown]
# <img src="./images/canary.png" alt="canary-deployment" width="500"/>

# %% [markdown]
# #### 🎯 Ideia central

# %% [markdown]
# O **Canary Deployment** é uma estratégia de rollout onde **uma nova versão da aplicação é liberada gradualmente** para uma pequena parcela dos usuários antes de ser disponibilizada para todos.

# %% [markdown]
# #### Benefícios

# %% [markdown]
# 1. **Redução de riscos**
#
#    - Permite detectar falhas, erros de performance ou regressões **sem impactar todos os usuários**.
#    - Facilita o _rollback_ rápido caso algo dê errado, bastando redirecionar o tráfego de volta à versão anterior.
#
# 2. **Feedback real de produção**
#
#    - É possível **avaliar métricas reais** (latência, taxa de erro, uso de CPU, etc.) antes de fazer o rollout completo.
#    - Gera dados valiosos para validar hipóteses ou novas features em ambiente real.
#
# 3. **Menor downtime percebido**
#
#    - A mudança é feita de forma incremental, evitando períodos longos de indisponibilidade.
#    - Usuários geralmente nem percebem a atualização acontecendo.
#
# 4. **Combina bem com observabilidade e automação**
#    - Pode ser facilmente integrado com sistemas de _monitoramento contínuo_ e _pipelines de CI/CD_.
#    - Implementações automatizadas podem até “promover” a nova versão sozinhas se as métricas estiverem dentro do esperado.

# %% [markdown]
# #### ⚠️ Quando **NÃO** usar

# %% [markdown]
# 1. **Aplicações com estado (stateful)**
#
#    - Se a aplicação mantém sessões ou dados em memória (ex: cache de sessão, fila local, etc.), dividir o tráfego entre versões pode gerar **inconsistências** ou **erros intermitentes**.
#
# 2. **Sistemas com tráfego baixo**
#
#    - Se há poucos usuários, o _canary_ pode não gerar dados estatisticamente relevantes — ou seja, você **não consegue validar** se a versão é realmente estável.
#
# 3. **Ambientes sem bom monitoramento**
#    - O sucesso do canary depende de **métricas e alertas confiáveis**.
#    - Se você não tem visibilidade sobre erros, latência ou experiência do usuário, o canary perde sentido.

# %% [markdown]
# ### 👥 Shadow Deployment

# %% [markdown]
# <img src="./images/shadow-deployment.png" alt="shadow-deploy" width="500"/>

# %% [markdown]
# #### 🎯 Ideia central

# %% [markdown]
# O **Shadow Deployment** (ou _Shadow Launch_) é uma estratégia de implantação onde **a nova versão da aplicação é executada em paralelo** à versão atual, **recebendo o mesmo tráfego real**, mas **sem impactar os usuários**.
#
# Em outras palavras:
#
# - Os usuários continuam interagindo **com a versão de produção (ativa)**.
# - O tráfego é **“espelhado”** (duplicado) e enviado também para a nova versão (_shadow_), apenas para **observação e análise**.
#
# O objetivo é **avaliar o comportamento da nova versão em condições reais**, sem correr o risco de afetar a experiência dos clientes.

# %% [markdown]
# #### Benefícios

# %% [markdown]
# 1. **Testes com tráfego real, sem impacto no usuário**
#
#    - É a melhor forma de validar **performance, escalabilidade e comportamento funcional** da nova versão com **dados reais de produção**.
#    - Permite detectar gargalos, erros de integração e problemas de latência antes do rollout oficial.
#
# 2. **Avaliação detalhada de métricas e logs**
#
#    - As requisições enviadas à versão _shadow_ podem ser comparadas com as da versão ativa (respostas, tempos, consumo de recursos, etc.).
#    - Essa análise ajuda a detectar **diferenças sutis** entre versões que testes sintéticos talvez não revelem.
#
# 3. **Sem downtime ou rollback necessário**
#
#    - Como os usuários não são afetados, não há necessidade de rollback em caso de falha.
#    - A nova versão pode ser descartada ou ajustada livremente até estar madura o suficiente.
#
# 4. **Ideal para validação de modelos de machine learning**
#    - É amplamente usado em **MLOps** para comparar previsões de modelos (novo vs antigo) em tempo real, garantindo que o novo modelo se comporte como esperado antes da promoção.

# %% [markdown]
# #### ⚠️ Quando **NÃO** usar

# %% [markdown]
# 1. **Alto custo de infraestrutura**
#
#    - O tráfego é duplicado: isso significa **dobrar a carga nos serviços downstream** (como bancos de dados, APIs e filas).
#    - Em sistemas de alto volume, isso pode **aumentar significativamente os custos** ou até gerar sobrecarga.
#
# 2. **Sistemas com efeitos colaterais (side effects)**
#
#    - Se a aplicação executa ações com efeito permanente (como enviar e-mails, processar pagamentos ou alterar dados), o _shadow_ pode **causar duplicação de eventos**.
#    - É necessário garantir que a versão _shadow_ **não produza efeitos reais**, normalmente por meio de mocks ou isolamento.
#
# 3. **Complexidade de roteamento e análise**
#    - Requer infraestrutura para **espelhar o tráfego**, armazenar logs e comparar resultados.
#    - Em ambientes sem ferramentas adequadas (como observabilidade robusta), a implementação se torna complexa.

# %% [markdown]
# ## 5 - Artefatos

# %% [markdown]
# ### 🎯 Objetivo

# %% [markdown]
# Entender **quais artefatos são produzidos após o treino** e **como eles são usados em MLOps** para garantir reprodutibilidade, rastreabilidade e automação.

# %% [markdown]
# ### 1. 🧠 Modelo serializado

# %% [markdown]
# Após o treinamento, o modelo precisa ser **salvo em um formato reutilizável**, isto é, serializado.
#
# Essa serialização transforma os pesos, parâmetros e estrutura do modelo em um arquivo que pode ser carregado posteriormente para fazer predições.

# %% [markdown]
# **Exemplos de formatos:**
#
# - `pickle` / `joblib` → modelos scikit-learn
# - `model.pt` → PyTorch
# - `model.h5` / `saved_model.pb` → TensorFlow/Keras
# - `onnx` → formato padrão para interoperabilidade entre frameworks

# %% [markdown]
# #### Salvando o modelo

# %%
from sklearn.datasets import make_classification
import pandas as pd

X, y = make_classification(
    n_samples=50,
    n_features=4,
    n_informative=3,
    n_redundant=1,
    n_classes=2,
    random_state=42,
)

df = pd.DataFrame(X, columns=["feature_1", "feature_2", "feature_3", "feature_4"])
df["target"] = y

df.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  target
# 0   0.008354  -1.193263   1.286766   1.204759       0
# 1   0.651517   1.089603   1.195353   1.112617       1
# 2  -0.285335   1.050135   0.610346   1.747551       1
# 3   1.294865  -0.468735   0.772646  -1.162324       0
# 4   0.981347   0.848851   0.563522  -0.368489       1

# %%
# Exemplo: salvando e carregando um modelo com scikit-learn
from sklearn.ensemble import RandomForestClassifier
import joblib

model = RandomForestClassifier().fit(X, y)
joblib.dump(model, "modelo_treinado.pkl")
# Out:
# ['modelo_treinado.pkl']

# %%
modelo_carregado = joblib.load("modelo_treinado.pkl")

modelo_carregado.predict(X[:5])
# Out:
# array([0, 1, 1, 0, 1])

# %% [markdown]
# ### 📦 Dependências e ambiente

# %% [markdown]
# Um modelo não funciona isoladamente, ele depende de bibliotecas e versões específicas.
#
# Para garantir que ele rode da mesma forma em outro ambiente (produção, nuvem, etc), é essencial capturar as dependências.

# %% [markdown]
# **Formas de registrar o ambiente:**
#
# - `requirements.txt` → Python
# - `environment.yml` → Conda
# - `pyproject.toml` → uv

# %% [markdown]
# ```python
# # Exemplo: gerar o arquivo requirements.txt
# pip freeze > requirements.txt
#
# ```

# %% [markdown]
# ### 👨🏻‍💻Código de Inferência

# %% [markdown]
# O modelo treinado precisa ser integrado em código que saiba:
#
# 1. Receber dados de entrada
# 2. Pré-processá-los
# 3. Carregar o modelo serializado
# 4. Fazer a predição
# 5. Retornar a saída no formato esperado

# %% [markdown]
# ```python
# # Exemplo: código de inferência
# import joblib
# import numpy as np
#
# # Carrega o modelo
# model = joblib.load("modelo_treinado.pkl")
#
# def inferencia(dados):
#     entrada = np.array(dados).reshape(1, -1)
#     predicao = model.predict(entrada)
#     return predicao
#
# ```

# %% [markdown]
# > Em produção, esse código normalmente é empacotado em uma API (Flask, FastAPI e etc.) e/ou em container Docker.

# %% [markdown]
# #### 🧭 Como esses artefatos se conectam no fluxo MLOps

# %% [markdown]
# | Artefato             | Função                                  | Onde é Usado              |
# | -------------------- | --------------------------------------- | ------------------------- |
# | Modelo serializado   | Contém os pesos e arquitetura do modelo | Deploy e inferência       |
# | Dependências         | Garante ambiente idêntico               | Reprodutibilidade e CI/CD |
# | Código de inferência | Define como o modelo é chamado          | API, serviço, batch job   |

# %% [markdown]
# ## 6 - Formas de servir modelos

# %% [markdown]
# ### 📊 Meios de processamento da inferência

# %% [markdown]
# #### 🧠 Batch Prediction vs. Online Prediction
#
# Quando falamos de **implantação de modelos de Machine Learning**, uma das primeiras decisões que precisamos tomar é:
#
# > **Como as previsões serão geradas e entregues aos usuários finais?**
#
# Existem **duas abordagens principais**:
#
# - **Online Prediction (ou Synchronous Prediction)**
# - **Batch Prediction (ou Asynchronous Prediction)**

# %% [markdown]
# #### ⚡ Online Prediction (Predição em Tempo Real)

# %% [markdown]
# **🕒 O que é?**
#
# As previsões são geradas **imediatamente** quando o sistema recebe uma requisição.
#
# > 👉 Ou seja, o modelo é executado **no momento da solicitação**.
#
# **💡 Exemplo prático**
# Imagine o **Google Tradutor**:
#
# - Você digita uma frase em inglês.
# - Em **milissegundos**, o modelo retorna a tradução em francês.
#
# **🔌 Como funciona na prática**
# Normalmente, o sistema de predição online é exposto via **APIs REST** (HTTP).
# Essas APIs recebem uma entrada (input), fazem a inferência e retornam a saída (output), tudo dentro do fluxo da requisição.

# %% [markdown]
# > Usuário → API de Predição → Modelo → Resultado Imediato

# %% [markdown]
# <img src="./images/online-prediction.png" alt="Online prediction diagram" width="500"/>

# %% [markdown]
# #### 🗂️ Batch Prediction (Predição em Lote)

# %% [markdown]
# **🕒 O que é?**
# As previsões são geradas **periodicamente** ou **sob demanda**, e **armazenadas** para uso posterior.
#
# > 👉 As predições são feitas **antes** da solicitação do usuário.
#
# **💡 Exemplo prático**
# Pense na **Netflix**:
#
# - O sistema gera recomendações de filmes **para todos os usuários** a cada 4 horas.
# - Quando o usuário entra na plataforma, as recomendações **já estão prontas**.
#
# **🧱 Como funciona na prática**
# As previsões geralmente são salvas em:
#
# - **Tabelas SQL**
# - **Arquivos CSV**
# - **Data Lakes**
#
# E são recuperadas conforme necessário.

# %% [markdown]
# <img src="./images/batch-prediction.png" alt="Batch prediction diagram" width="800"/>

# %% [markdown]
# > Modelo → Gera previsões em lote → Armazena → Usuário acessa o resultado pronto

# %% [markdown]
# #### Batch e streaming features

# %% [markdown]
# **📚 Batch Features**
#
# São **features derivadas de dados históricos**, normalmente armazenadas em bancos de dados ou data warehouses.
#
# > Exemplo: tempo médio de preparo de um restaurante nos últimos 30 dias.
#
# Essas features são calculadas periodicamente, não mudam a cada segundo, apenas quando o pipeline de dados é executado novamente.
#
# ---
#
# **Streaming Features**
#
# São **features calculadas em tempo real**, baseadas em dados que fluem continuamente por sistemas de mensageria (Kafka, Pub/Sub, Kinesis etc.).
#
# > Exemplo: número atual de pedidos em andamento ou quantos entregadores estão disponíveis agora.

# %% [markdown]
# **🍔 Exemplo prático — Ifood**
#
# Após um pedido ser feito, o sistema pode precisar de ambos os tipos de features para prever o **tempo de entrega**:
#
# | Tipo de Feature       | Exemplo                                                   | Origem                               |
# | --------------------- | --------------------------------------------------------- | ------------------------------------ |
# | **Batch Feature**     | Tempo médio de preparo do restaurante nas últimas semanas | Histórico (Data Warehouse)           |
# | **Streaming Feature** | Quantos pedidos estão sendo preparados **neste momento**  | Dados em tempo real (Kafka, Pub/Sub) |

# %% [markdown]
# <img src="./images/online-prediction-feature-streaming.png" alt="Online prediction feature streaming" width="800"/>

# %% [markdown]
# #### 🔄 Resumo Comparativo

# %% [markdown]
# | Característica                   | Online Prediction (Synchronous)    | Batch Prediction (Asynchronous) |
# | -------------------------------- | ---------------------------------- | ------------------------------- |
# | **Tempo de resposta**            | Imediato (em tempo real)           | Agendado ou sob demanda         |
# | **Exemplo**                      | Google Translate                   | Netflix Recommendations         |
# | **Forma de execução**            | Via API (HTTP, REST)               | Scripts/Jobs agendados          |
# | **Armazenamento dos resultados** | Não (resultado direto na resposta) | Sim (CSV, SQL, Data Lake)       |
# | **Custo de infraestrutura**      | Alto (modelo sempre ativo)         | Mais baixo (execução pontual)   |
# | **Latência tolerada**            | Baixa                              | Alta                            |

# %% [markdown]
# #### Streaming serving

# %% [markdown]
# **🚀 O que é?**
#
# O modelo recebe **um fluxo contínuo de dados** (stream) e **gera previsões em tempo real** conforme os eventos chegam, sem depender de requisições HTTP explícitas.
#
# > É como colocar o modelo "dentro" do pipeline de streaming.
#
# **💡 Exemplo prático**
#
# Um sistema de **detecção de fraude** em cartões de crédito:
#
# - Cada transação é processada **assim que ocorre**.
# - O modelo decide em milissegundos se deve aprovar ou bloquear a operação.
#
# **🔌 Como funciona**
#
# O modelo é integrado a um **pipeline de dados streaming**, como Kafka, Flink, Spark Streaming ou Dataflow.

# %% [markdown]
# > Kafka Topic → Modelo de ML → Sink (ex: banco, alerta, API)

# %% [markdown]
# **✅ Vantagens**
#
# - **Baixíssima latência** (milissegundos).
# - Ideal para **casos em que o tempo é crítico**.
# - Escalável e reativo a fluxos contínuos.
#
# **Desvantagens**
#
# - Requer **infraestrutura complexa** de stream processing.
# - Dificuldade maior de **debug e monitoramento** em tempo real.

# %% [markdown]
# #### Event-driven serving

# %% [markdown]
# **⚙️ O que é?**
#
# O modelo é **acionado automaticamente por eventos** específicos, não por streams contínuos nem por requisições diretas.
#
# > 👉 O modelo “acorda” apenas quando algo relevante acontece.
#
# **Exemplo prático**
#
# - Um modelo de **churn prediction** é acionado quando um cliente cancela uma assinatura;
# - Um modelo de **previsão de demanda** roda quando um novo lote de dados é carregado em um bucket (ex: arquivo CSV no S3).
#
# **🔌 Como funciona**
# O modelo é ativado via **gatilhos (triggers)**, como eventos em filas, uploads de arquivos, ou mensagens pub/sub.

# %% [markdown]
# <img src="./images/event-inference.png" alt="Event Inference Diagram" width="800"/>

# %% [markdown]
# ### Padrões de _Model Serving_

# %% [markdown]
# Depois de encontrar um modelo adequado, o próximo passo é decidir **como ele será disponibilizado e utilizado em produção**.
#
# Existem diferentes **padrões arquiteturais** para fazer o _serving_ de modelos de machine learning, cada um com seus prós e contras.

# %% [markdown]
# #### Embedded Model (Modelo Embutido)

# %% [markdown]
# **⚙️ O que é?**
#
# Neste padrão, o modelo é **empacotado junto com a aplicação** que o consome.
#
# Ou seja, o artefato do modelo (por exemplo, um `.pkl` ou `.onnx`) é tratado como uma **dependência do próprio código da aplicação**.

# %% [markdown]
# > Aplicação + Modelo = Um único artefato versionado

# %% [markdown]
# **💡 Exemplo prático**
#
# Um app mobile de recomendação que inclui um modelo treinado localmente dentro do pacote da aplicação.
#
# **✅ Vantagens**
#
# - Simplicidade: não há infraestrutura extra de serving.
# - Baixa latência: o modelo roda localmente na aplicação.
# - Facilita a distribuição offline (ex: edge devices, mobile apps).
#
# **⚠️ Desvantagens**
#
# - Atualizar o modelo exige **nova versão da aplicação**.
# - Dificulta o monitoramento centralizado e rollback de versões.
# - Pouco flexível para cenários com múltiplos modelos.
#
# ---

# %% [markdown]
# #### ☁️ Model Deployed as a Separate Service

# %% [markdown]
# **⚙️ O que é?**
#
# Aqui, o modelo é **implantado como um serviço independente**, acessado por outras aplicações via rede.
#
# É o padrão mais comum em sistemas modernos de MLOps.

# %% [markdown]
# > Aplicação → Chamada HTTP/gRPC → Serviço de Modelo

# %% [markdown]
# **💡 Exemplo prático**
#
# Uma API REST no **Amazon SageMaker Endpoint**, que recebe dados e retorna previsões.
#
# **✅ Vantagens**
#
# - **Desacoplamento total** entre aplicação e modelo.
# - Permite **atualizar o modelo sem redeploy da aplicação**.
# - Escalável horizontalmente conforme a demanda.
#
# **⚠️ Desvantagens**
#
# - **Maior latência**, pois há chamadas de rede.
# - Requer infraestrutura de serving e orquestração.
# - Complexidade maior de segurança e versionamento.

# %% [markdown]
# ## Referências

# %% [markdown]
# ### 📚 Livros
#
# - **[Design Machine Learning Systems: An Iterative Process for Production-ready applications](https://a.co/d/asHVqb5)**
#   _Chip Huyen_
#
# - **[Machine Learning Engineering with Python: Manage the lifecycle of machine learning models using MLOps with practical examples](https://a.co/d/7M89nsf)**
#   _Andrew P. McMahon e Adi Polak_
#
# ---
#
# ### 📝 Artigos
#
# - [What is MLOps (AWS)](https://aws.amazon.com/what-is/mlops/?nc1=h_ls)
# - [CS 329S. Lecture 8. Deployment (Stanford)](https://docs.google.com/document/d/1hNuW6bqWYZjlwpit_8W1cu7kllb-jTfy3Liof1GJWug/edit?tab=t.0)
# - [Continuous Delivery for Machine Learning (Martin Fowler)](https://martinfowler.com/articles/cd4ml.html)
