# %% [markdown]
# # Prova Seleção - Formação em Engenharia de Machine Learning

# %% [markdown]
# ## Por que essa prova existe?
#
# Queremos oferecer uma formação em Engenharia de Machine Learning para pessoas que já possuem um background em TI.
#
# No entento, para que essa formação seja proveitosa, é importante possuir um conhecimento mínimo sobre alguns temas que fazem parte do dia-a-dia de uma pessoa que atua como Eng. de ML. Essa prova visa avaliar alguns destes tópicos.
#
# Sendo eles:
#
# - Python;
# - AWS;
# - Machine Learning;

# %% [markdown]
# ## Regras
#
# * Você `pode e deve` usar a internet, IAs Generativas ou qualquer outra fonte que considerar válida para responder as questões. No entanto, `escreva as respostas com as suas próprias palavras`. Plágio ou respostas geradas por IAs irão te desclassificar automaticamente;
#
# * Algumas perguntas não possuem resposta "certa", queremos entender o seu raciocínio.

# %% [markdown]
# # 1 - Python e Programação

# %% [markdown]
# ## 1.1 - Qual a diferença entre tuplas e listas? Cite um cenário em que usar tuplas pode ser mais vantajoso.

# %% [markdown]
# Sua resposta aqui

# %% [markdown]
# ## 1.2 - Escreva uma função para gerar os números ímpares até o `limite`.
#
# Importante: considere o `limite` um número inteiro maior ou igual à zero.

# %%
from typing import List

def gera_impares(limite: int) -> List[int]:
    """
    Gera os números ímpares até o `limite`.

    Se o `limite` for um número ímpar, ele deve ser incluído no retorno também.

    Args:
        - limite: inteiro que até onde os ímpares serão gerados.

    Retorno:
        - Uma lista com todos os números ímpares até o limite.
    """

    # SEU CÓDIGO AQUI
    return []

print('Ímpares no intervalo [0,0]:',gera_impares(limite=0))
print('Ímpares no intervalo [0,7]:',gera_impares(limite=7))
print('Ímpares no intervalo [0,8]:',gera_impares(limite=8))
# Out:
# Ímpares no intervalo [0,0]: []
# Ímpares no intervalo [0,7]: []
# Ímpares no intervalo [0,8]: []

# %% [markdown]
# ## 1.3 - O que são testes unitários? Crie os casos de teste para a sua função `gera_impares`.

# %% [markdown]
# SUA RESPOSTA

# %% [markdown]
# ## 1.4 - O Python possui tipagem dinâmica. O que isso significa? Forneça um exemplo.

# %% [markdown]
# SUA RESPOSTA

# %% [markdown]
# # 2 - AWS

# %% [markdown]
# ## 2.1 - Qual a diferença entre o AWS EC2 e o AWS S3? Dê um exemplo de uso para cada um destes serviços.

# %% [markdown]
# SUA RESPOSTA

# %% [markdown]
# ## 2.2 - O que são os serviços AWS Lambda e AWS ECS? Supondo que você quer realizar um deploy de uma rotina que leva em média 10 minutos para concluir sua execução, qual destes serviços você usaria? Justifique

# %% [markdown]
# SUA RESPOSTA

# %% [markdown]
# ## 2.3 - O que é o AWS CloudWatch? Qual a diferença entre métrica, alarme e log.

# %% [markdown]
# SUA RESPOSTA

# %% [markdown]
# # 3 - Dados e Machine Learning

# %% [markdown]
# ## 3.1 - Qual a diferença entre dados estruturados e não estruturados?

# %% [markdown]
# ## 3.2 - Considerando o contexto de Machine Learning, explique o que é o treinamento. Quais os tipos de treinamento existentes?

# %% [markdown]
# ## 3.3 - Qual a diferença entre Data e Concept drift?
